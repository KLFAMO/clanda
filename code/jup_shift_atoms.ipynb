# %%
# %matplotlib widget
from shift import Shift_sqr, Shift_lin
from ml_data import mlatoms

# %%
sh = Shift_lin(
    mes=mlatoms,
)

sh.fit()
sh.plot()
# Out:
# a =  -1.4514468026965513e-06
# a err =  3.0240820073582586e-06
# u: 2.4374209018838635e-05
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
