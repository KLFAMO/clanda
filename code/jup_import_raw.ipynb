# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib widget

from cmpmaker.runner import calc

# %%
mjd = 60795
calc(
    script_name="get_raw",
    from_mjd=mjd,
    to_mjd=mjd + 1 - 1e-6,
    names = ["sr1_aom_cor_ml2", "sr1_atoms_ml2", "sr1_prob_ml2"]
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 mjd = 60795
# ----> 2 calc(
#       3     script_path="get_raw",
#       4     from_mjd=mjd,
#       5     to_mjd=mjd + 1 - 1e-6,
#       6     names = ["sr1_aom_cor_ml2", "sr1_atoms_ml2", "sr1_prob_ml2"]
#       7 )
#
# TypeError: calc() missing 1 required positional argument: 'script_name'
