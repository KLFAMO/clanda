# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib widget

from dataio.mts import get_data_single_mjd, get_data_names, set_flags_in_range

# %%
for i in get_data_names():
    print(i)
# Out:
# comb_frep_dm
# comb_hydro_698
# comb_hydro_698_notrack
# rls_hydro_cavity_beat
# sr1_aom_cor
# sr1_atoms
# sr1_prob

# %%
mjd = 60790

# %%
dataset = "rls_hydro_cavity_beat"
a = get_data_single_mjd(dataset, mjd)
a.plotf()
# Out:
# Loading data from: /home/stront/svnSr/progs/clanda/npdata/rls_hydro_cavity_beat/60790/rls_hydro_cavity_beat_60790_raw.npz
# /home/stront/svnSr/progs/clanda/npdata/rls_hydro_cavity_beat/60790/rls_hydro_cavity_beat_60790_raw.npz
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dataset = "comb_hydro_698"
a = get_data_single_mjd(dataset, mjd)
a.plotf()
# Out:
# Loading data from: /home/stront/svnSr/progs/clanda/npdata/comb_hydro_698/60790/comb_hydro_698_60790_raw.npz
# /home/stront/svnSr/progs/clanda/npdata/comb_hydro_698/60790/comb_hydro_698_60790_raw.npz
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dataset = "comb_hydro_698_notrack"
a = get_data_single_mjd(dataset, mjd)
a.plotf()
# Out:
# Loading data from: /home/stront/svnSr/progs/clanda/npdata/comb_hydro_698_notrack/60790/comb_hydro_698_notrack_60790_raw.npz
# /home/stront/svnSr/progs/clanda/npdata/comb_hydro_698_notrack/60790/comb_hydro_698_notrack_60790_raw.npz
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dataset = "sr1_aom_cor"
a = get_data_single_mjd(dataset, mjd)
a.plotf()
# Out:
# Loading data from: /home/stront/svnSr/progs/clanda/npdata/sr1_aom_cor/60790/sr1_aom_cor_60790_raw.npz
# /home/stront/svnSr/progs/clanda/npdata/sr1_aom_cor/60790/sr1_aom_cor_60790_raw.npz
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dataset = "sr1_atoms"
a = get_data_single_mjd(dataset, mjd)
a.plotf()
# Out:
# Loading data from: /home/stront/svnSr/progs/clanda/npdata/sr1_atoms/60790/sr1_atoms_60790_raw.npz
# /home/stront/svnSr/progs/clanda/npdata/sr1_atoms/60790/sr1_atoms_60790_raw.npz
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dataset = "sr1_prob"
a = get_data_single_mjd(dataset, mjd)
a.plotf()
# Out:
# Loading data from: /home/stront/svnSr/progs/clanda/npdata/sr1_prob/60790/sr1_prob_60790_raw.npz
# /home/stront/svnSr/progs/clanda/npdata/sr1_prob/60790/sr1_prob_60790_raw.npz
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# set_flags_in_range(
#         dataset=dataset,
#         from_mjd=,
#         to_mjd=rm_period[1],
#         flag_value=0
#     )
