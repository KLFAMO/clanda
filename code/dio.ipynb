# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib widget

from dataio.mts import get_data_single_mjd, get_data_names, set_flags_in_range

# %%
for i in get_data_names():
    print(i)
# Out:
# ['comb_hydro_698', 'comb_hydro_698_notrack', 'rls_hydro_cavity_beat', 'sr1_aom_cor', 'sr1_atoms', 'sr1_prob']

# %%
dataset = "rls_hydro_cavity_beat"
a = get_data_single_mjd(dataset, 60760)
a.plotf()
# Out:
# Loading data from: /home/stront/svnSr/progs/clanda/npdata/rls_hydro_cavity_beat/60760/rls_hydro_cavity_beat_60760_raw.npz
# /home/stront/svnSr/progs/clanda/npdata/rls_hydro_cavity_beat/60760/rls_hydro_cavity_beat_60760_raw.npz
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dataset = "comb_hydro_698"
a = get_data_single_mjd(dataset, 60760)
a.plotf()
# Out:
# Loading data from: /home/stront/svnSr/progs/clanda/npdata/comb_hydro_698/60760/comb_hydro_698_60760_raw.npz
# /home/stront/svnSr/progs/clanda/npdata/comb_hydro_698/60760/comb_hydro_698_60760_raw.npz
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dataset = "comb_hydro_698_notrack"
a = get_data_single_mjd(dataset, 60760)
a.plotf()
# Out:
# Loading data from: /home/stront/svnSr/progs/clanda/npdata/comb_hydro_698_notrack/60760/comb_hydro_698_notrack_60760_raw.npz
# /home/stront/svnSr/progs/clanda/npdata/comb_hydro_698_notrack/60760/comb_hydro_698_notrack_60760_raw.npz
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dataset = "sr1_aom_cor"
a = get_data_single_mjd(dataset, 60760)
a.plotf()
# Out:
# Loading data from: /home/stront/svnSr/progs/clanda/npdata/sr1_aom_cor/60760/sr1_aom_cor_60760_raw.npz
# /home/stront/svnSr/progs/clanda/npdata/sr1_aom_cor/60760/sr1_aom_cor_60760_raw.npz
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dataset = "sr1_atoms"
a = get_data_single_mjd(dataset, 60760)
a.plotf()
# Out:
# Loading data from: /home/stront/svnSr/progs/clanda/npdata/sr1_atoms/60760/sr1_atoms_60760_raw.npz
# /home/stront/svnSr/progs/clanda/npdata/sr1_atoms/60760/sr1_atoms_60760_raw.npz
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dataset = "sr1_prob"
a = get_data_single_mjd(dataset, 60760)
a.plotf()
# Out:
# Loading data from: /home/stront/svnSr/progs/clanda/npdata/sr1_prob/60760/sr1_prob_60760_raw.npz
# /home/stront/svnSr/progs/clanda/npdata/sr1_prob/60760/sr1_prob_60760_raw.npz
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
set_flags_in_range(
        dataset=dataset,
        from_mjd=,
        to_mjd=rm_period[1],
        flag_value=0
    )
# Out:
#   Cell In[9], line 3
#     from_mjd=,
#     ^
# SyntaxError: expected argument value expression
