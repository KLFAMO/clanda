# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib widget

from dataio.mts import get_data_single_mjd, get_data_names, set_flags_in_range, set_flags_in_area

# %%
mjd = 60790
dataset = "sr1_prob"
# set_flags_in_area(dataset, 60790, 44587500.017, 60791, -1e10, 0)
a = get_data_single_mjd(dataset, mjd)
a.flag_filter(1)
a.plotf()
# a.plot_allan()
# Out:
# Loading data from: /home/stront/svnSr/progs/clanda/npdata/sr1_prob/60790/sr1_prob_60790_raw.npz
# /home/stront/svnSr/progs/clanda/npdata/sr1_prob/60790/sr1_prob_60790_raw.npz
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
