# %%
# %matplotlib widget
from shift import Shift_sqr, Shift_lin
from ml_data import ml698pd

# %%
sh = Shift_lin(
    mes=ml698pd,
)

sh.fit()
sh.plot()
# Out:
# a =  -0.03820190903837275
# a err =  0.0005967293021292325
# u: 0.005175044348738686
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
