# %%
# %matplotlib widget
from shift import Shift_sqr, Shift_lin
from ml_data import ml698pd

# %%
sh = Shift_lin(
    mes=ml698pd,
)

sh.fit()
sh.plot()
# Out:
# a =  -0.15280763603908315
# a err =  0.0005967293049471959
# u: 0.009028181083368053
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
