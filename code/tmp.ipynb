# %%
# %matplotlib widget
import ml
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/svnSr/progs/clanda/code/ml.py:12
#       7 from ml_data import mlb as m
#       8 # from ml_data import ml698 as m
#       9 # from ml_data import ml698b as m
#      10 # from ml_data import ml813 as m
#      11 # from ml_data import mlatoms as m
# ---> 12 from get_data_test import get_data
#      16 gts = get_data(
#      17     included_tables={
#      18         "sr1_ml1_f": {'sh_s':0, 'tol_s':5},
#    (...)     27     mjd_range=m[4]['range'],
#      28 )
#      30 gts.math_mts_and_number('multiply', 'sr1_ml1_f', -1, 'mml1_f')
#
# File ~/svnSr/progs/clanda/code/get_data_test.py:1
# ----> 1 from timanda.tserie import TSerie, MTSerie, GTserie, load_gts
#       2 from rm_data import rm_periods, rm_periods_link, rm_periods_ml
#       4 # Correction data for the 698 Sr clock
#       5 # cor = [
# ...
