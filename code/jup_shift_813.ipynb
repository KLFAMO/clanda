# %%
# %matplotlib widget
from shift import Shift_sqr, Shift_lin
from ml_data import ml813

# %%
sh = Shift_lin(
    mes=ml813,
)

sh.fit()
sh.plot()
# Out:
# a =  -0.0008923056642172043
# a err =  6.029480816533134e-05
# u: 0.0004880198208786653
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
