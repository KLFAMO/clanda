# %%
# %matplotlib widget
from shift import Shift_sqr
from ml_data import mlb

# %%
sh = Shift_sqr(
    mes=mlb
)

sh.fit()
sh.plot()
# Out:
# xw:  -0.001843535237851729
# yw:  0.014607114441177968
# a =  -4297.951845415076
# b =  -15.84685135522512
# a err =  2.2903600353750155
# b err =  1.071067237578382
# u = 0.6740736097391431
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
