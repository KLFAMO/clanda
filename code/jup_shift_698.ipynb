# %%
# %matplotlib widget
from shift import Shift_sqr, Shift_lin
from ml_data import ml698

# %%
sh = Shift_lin(
    mes=ml698,
)

sh.fit()
sh.plot()
# Out:
# a =  -2.6994622591136395
# a err =  0.005914615575456116
# u: 0.1431444790512109
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
